# %%
# %load_ext sql
# %sql postgresql://admin:trading@localhost:5432/trading
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# %config SqlMagic.displaylimit = 100

# %%
# %%sql
# SELECT * FROM trading.members;
# Out:
#  * postgresql://admin:***@localhost:5432/trading
# 14 rows affected.
# [('c4ca42', 'Danny', 'Australia'),
#  ('c81e72', 'Vipul', 'United States'),
#  ('eccbc8', 'Charlie', 'United States'),
#  ('a87ff6', 'Nandita', 'United States'),
#  ('e4da3b', 'Rowan', 'United States'),
#  ('167909', 'Ayush', 'United States'),
#  ('8f14e4', 'Alex', 'United States'),
#  ('c9f0f8', 'Abe', 'United States'),
#  ('45c48c', 'Ben', 'Australia'),
#  ('d3d944', 'Enoch', 'Africa'),
#  ('6512bd', 'Vikram', 'India'),
#  ('c20ad4', 'Leah', 'Asia'),
#  ('c51ce4', 'Pavan', 'Australia'),
#  ('aab323', 'Sonia', 'Australia')]

# %%
# %%sql
# SELECT * FROM trading.prices LIMIT 5;
# Out:
#  * postgresql://admin:***@localhost:5432/trading
# 5 rows affected.
# [('ETH', datetime.date(2021, 8, 29), 3177.84, 3243.96, 3282.21, 3162.79, '582.04K', '-2.04%'),
#  ('ETH', datetime.date(2021, 8, 28), 3243.9, 3273.78, 3284.58, 3212.24, '466.21K', '-0.91%'),
#  ('ETH', datetime.date(2021, 8, 27), 3273.58, 3093.78, 3279.93, 3063.37, '839.54K', '5.82%'),
#  ('ETH', datetime.date(2021, 8, 26), 3093.54, 3228.03, 3249.62, 3057.48, '118.44K', '-4.17%'),
#  ('ETH', datetime.date(2021, 8, 25), 3228.15, 3172.12, 3247.43, 3080.7, '923.13K', '1.73%')]

# %%
# %%sql
# SELECT * FROM trading.transactions LIMIT 5;
# Out:
#  * postgresql://admin:***@localhost:5432/trading
# 5 rows affected.
# [(1, 'c81e72', 'BTC', datetime.date(2017, 1, 1), 'BUY', 50.0, 0.3, datetime.datetime(2017, 1, 1, 0, 0)),
#  (2, 'eccbc8', 'BTC', datetime.date(2017, 1, 1), 'BUY', 50.0, 0.3, datetime.datetime(2017, 1, 1, 0, 0)),
#  (3, 'a87ff6', 'BTC', datetime.date(2017, 1, 1), 'BUY', 50.0, 0.0, datetime.datetime(2017, 1, 1, 0, 0)),
#  (4, 'e4da3b', 'BTC', datetime.date(2017, 1, 1), 'BUY', 50.0, 0.3, datetime.datetime(2017, 1, 1, 0, 0)),
#  (5, '167909', 'BTC', datetime.date(2017, 1, 1), 'BUY', 50.0, 0.3, datetime.datetime(2017, 1, 1, 0, 0))]
