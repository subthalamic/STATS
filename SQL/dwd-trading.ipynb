# %%
# %load_ext sql
# %sql postgresql://admin:trading@localhost:5432/trading

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# %config SqlMagic.displaylimit = 100

# %%
# %%sql
# WITH cte_ranked AS (
# SELECT
#   member_id,
#   DATE_TRUNC('MON', txn_date)::DATE AS calendar_month,
#   SUM(quantity) AS sold_eth_quantity,
#   RANK() OVER (PARTITION BY member_id ORDER BY SUM(quantity) DESC) AS month_rank
# FROM trading.transactions
# WHERE ticker = 'ETH' AND txn_type = 'SELL'
# GROUP BY member_id, calendar_month
# )
# SELECT
#   member_id,
#   calendar_month,
#   sold_eth_quantity
# FROM cte_ranked
# WHERE month_rank = 1
# ORDER BY sold_eth_quantity DESC;
# Out:
#  * postgresql://admin:***@localhost:5432/trading
# 14 rows affected.
# [('c51ce4', datetime.date(2017, 5, 1), 66.09244042953502),
#  ('d3d944', datetime.date(2020, 4, 1), 60.41736997398335),
#  ('6512bd', datetime.date(2018, 5, 1), 47.93285714951591),
#  ('167909', datetime.date(2020, 12, 1), 45.92423664055218),
#  ('c81e72', datetime.date(2018, 8, 1), 41.26728177476413),
#  ('aab323', datetime.date(2018, 9, 1), 41.175076337098375),
#  ('c4ca42', datetime.date(2021, 4, 1), 40.11347472402257),
#  ('c20ad4', datetime.date(2017, 12, 1), 37.71908498970638),
#  ('eccbc8', datetime.date(2021, 3, 1), 36.485934922948275),
#  ('8f14e4', datetime.date(2017, 7, 1), 36.173837436812306),
#  ('e4da3b', datetime.date(2019, 1, 1), 30.484426410776322),
#  ('a87ff6', datetime.date(2020, 7, 1), 27.28919836842423),
#  ('45c48c', datetime.date(2020, 1, 1), 20.2152340642537),
#  ('c9f0f8', datetime.date(2020, 11, 1), 15.931855129247868)]

# %%
# %%sql
# SELECT
#   member_id,
#   DATE_TRUNC('MON', txn_date)::DATE AS calendar_month,
#   SUM(quantity) AS sold_eth_quantity,
#   RANK() OVER (PARTITION BY member_id ORDER BY SUM(quantity) DESC) AS month_rank
# FROM trading.transactions
# WHERE ticker = 'ETH' AND txn_type = 'SELL'
# GROUP BY member_id, calendar_month
# Out:
#  * postgresql://admin:***@localhost:5432/trading
# 669 rows affected.
# [('167909', datetime.date(2020, 12, 1), 45.92423664055218, 1),
#  ('167909', datetime.date(2019, 12, 1), 40.315975644861766, 2),
#  ('167909', datetime.date(2017, 2, 1), 29.659220904991273, 3),
#  ('167909', datetime.date(2020, 10, 1), 26.948516575979195, 4),
#  ('167909', datetime.date(2019, 4, 1), 26.03443708888612, 5),
#  ('167909', datetime.date(2020, 4, 1), 24.615125833830227, 6),
#  ('167909', datetime.date(2021, 6, 1), 23.98442375927094, 7),
#  ('167909', datetime.date(2017, 5, 1), 23.722624384411393, 8),
#  ('167909', datetime.date(2018, 12, 1), 23.0988648381609, 9),
#  ('167909', datetime.date(2018, 9, 1), 20.75796602261515, 10),
#  ('167909', datetime.date(2020, 6, 1), 20.69908768194086, 11),
#  ('167909', datetime.date(2019, 9, 1), 19.75700936512777, 12),
#  ('167909', datetime.date(2020, 3, 1), 19.107614946907848, 13),
#  ('167909', datetime.date(2017, 3, 1), 18.634303098129763, 14),
#  ('167909', datetime.date(2021, 4, 1), 17.97789697054209, 15),
#  ('167909', datetime.date(2017, 11, 1), 17.38899878233834, 16),
#  ('167909', datetime.date(2018, 1, 1), 17.36560591694176, 17),
#  ('167909', datetime.date(2017, 1, 1), 16.08815477837797, 18),
#  ('167909', datetime.date(2020, 5, 1), 15.979969564024511, 19),
#  ('167909', datetime.date(2019, 6, 1), 14.14861398564398, 20),
#  ('167909', datetime.date(2018, 8, 1), 13.80830269223328, 21),
#  ('167909', datetime.date(2017, 9, 1), 13.631404206661621, 22),
#  ('167909', datetime.date(2017, 12, 1), 13.44852537993116, 23),
#  ('167909', datetime.date(2018, 7, 1), 13.310982860587579, 24),
#  ('167909', datetime.date(2021, 5, 1), 12.34621012549941, 25),
#  ('167909', datetime.date(2017, 6, 1), 11.543834638502771, 26),
#  ('167909', datetime.date(2021, 1, 1), 11.27166811845491, 27),
#  ('167909', datetime.date(2020, 2, 1), 10.84898519764267, 28),
#  ('167909', datetime.date(2019, 2, 1), 10.489410824594858, 29),
#  ('167909', datetime.date(2018, 6, 1), 10.114833267625901, 30),
#  ('167909', datetime.date(2017, 7, 1), 9.50193228576161, 31),
#  ('167909', datetime.date(2020, 8, 1), 9.27965226703041, 32),
#  ('167909', datetime.date(2019, 11, 1), 9.09349887590952, 33),
#  ('167909', datetime.date(2018, 2, 1), 8.97545354137161, 34),
#  ('167909', datetime.date(2017, 8, 1), 8.50932300692804, 35),
#  ('167909', datetime.date(2019, 8, 1), 8.43677866545626, 36),
#  ('167909', datetime.date(2017, 4, 1), 7.8507290558878395, 37),
#  ('167909', datetime.date(2020, 9, 1), 7.37782740264176, 38),
#  ('167909', datetime.date(2021, 2, 1), 7.181013127556135, 39),
#  ('167909', datetime.date(2020, 1, 1), 6.333857282501219, 40),
#  ('167909', datetime.date(2019, 7, 1), 5.41355534726528, 41),
#  ('167909', datetime.date(2018, 4, 1), 5.38970459805412, 42),
#  ('167909', datetime.date(2017, 10, 1), 5.296808187033972, 43),
#  ('167909', datetime.date(2019, 1, 1), 5.28265795494381, 44),
#  ('167909', datetime.date(2018, 3, 1), 5.20340651743581, 45),
#  ('167909', datetime.date(2018, 11, 1), 2.79562346253034, 46),
#  ('167909', datetime.date(2021, 7, 1), 2.781590453843315, 47),
#  ('167909', datetime.date(2018, 5, 1), 2.5080756628896967, 48),
#  ('167909', datetime.date(2019, 5, 1), 2.17004250231941, 49),
#  ('167909', datetime.date(2018, 10, 1), 1.98110944278117, 50),
#  ('167909', datetime.date(2020, 7, 1), 1.69375847638914, 51),
#  ('167909', datetime.date(2021, 3, 1), 0.921526674196222, 52),
#  ('45c48c', datetime.date(2020, 1, 1), 20.2152340642537, 1),
#  ('45c48c', datetime.date(2019, 11, 1), 17.24465700586833, 2),
#  ('45c48c', datetime.date(2020, 11, 1), 17.17336039896974, 3),
#  ('45c48c', datetime.date(2019, 6, 1), 14.96827277405828, 4),
#  ('45c48c', datetime.date(2019, 10, 1), 13.73313106265918, 5),
#  ('45c48c', datetime.date(2021, 8, 1), 11.56655826132301, 6),
#  ('45c48c', datetime.date(2018, 6, 1), 11.37352631837984, 7),
#  ('45c48c', datetime.date(2020, 9, 1), 9.902741281820582, 8),
#  ('45c48c', datetime.date(2017, 4, 1), 8.64094251824984, 9),
#  ('45c48c', datetime.date(2017, 11, 1), 8.48762163322132, 10),
#  ('45c48c', datetime.date(2018, 4, 1), 8.3877722431265, 11),
#  ('45c48c', datetime.date(2019, 3, 1), 8.1994525449436, 12),
#  ('45c48c', datetime.date(2017, 3, 1), 6.86143390707141, 13),
#  ('45c48c', datetime.date(2020, 5, 1), 6.6434477747428, 14),
#  ('45c48c', datetime.date(2021, 6, 1), 6.48667573478381, 15),
#  ('45c48c', datetime.date(2018, 3, 1), 6.12390456531437, 16),
#  ('45c48c', datetime.date(2020, 8, 1), 5.96019844722765, 17),
#  ('45c48c', datetime.date(2021, 2, 1), 5.90027347618342, 18),
#  ('45c48c', datetime.date(2017, 12, 1), 5.54484235821608, 19),
#  ('45c48c', datetime.date(2018, 1, 1), 5.19505648977653, 20),
#  ('45c48c', datetime.date(2018, 5, 1), 4.46837412592167, 21),
#  ('45c48c', datetime.date(2020, 3, 1), 3.15126879711489, 22),
#  ('45c48c', datetime.date(2019, 9, 1), 2.5080305589432, 23),
#  ('45c48c', datetime.date(2019, 7, 1), 2.393887714681715, 24),
#  ('45c48c', datetime.date(2019, 5, 1), 2.05934770324273, 25),
#  ('45c48c', datetime.date(2021, 3, 1), 1.43744814801824, 26),
#  ('45c48c', datetime.date(2021, 4, 1), 0.738665802229725, 27),
#  ('45c48c', datetime.date(2018, 7, 1), 0.63965643287343, 28),
#  ('45c48c', datetime.date(2019, 2, 1), 0.275282246755317, 29),
#  ('45c48c', datetime.date(2017, 1, 1), 0.21676115944647, 30),
#  ('6512bd', datetime.date(2018, 5, 1), 47.93285714951591, 1),
#  ('6512bd', datetime.date(2020, 8, 1), 41.25888642308161, 2),
#  ('6512bd', datetime.date(2018, 3, 1), 33.3588600207095, 3),
#  ('6512bd', datetime.date(2020, 6, 1), 33.261234769289665, 4),
#  ('6512bd', datetime.date(2017, 9, 1), 29.909919523226073, 5),
#  ('6512bd', datetime.date(2018, 11, 1), 29.84129586865343, 6),
#  ('6512bd', datetime.date(2020, 10, 1), 28.777332268459897, 7),
#  ('6512bd', datetime.date(2018, 12, 1), 28.595864478397424, 8),
#  ('6512bd', datetime.date(2021, 1, 1), 27.316198464984787, 9),
#  ('6512bd', datetime.date(2021, 7, 1), 25.95666602792374, 10),
#  ('6512bd', datetime.date(2019, 1, 1), 25.225439668335, 11),
#  ('6512bd', datetime.date(2019, 7, 1), 24.782908298846174, 12),
#  ('6512bd', datetime.date(2020, 5, 1), 23.16197178144446, 13),
#  ('6512bd', datetime.date(2017, 2, 1), 22.793651450752957, 14),
#  ('6512bd', datetime.date(2019, 3, 1), 21.1798895097174, 15),
#  ('6512bd', datetime.date(2020, 1, 1), 21.03746052780113, 16),
#  ('6512bd', datetime.date(2018, 2, 1), 20.981068126134442, 17),
#  ('6512bd', datetime.date(2018, 10, 1), 20.95763785570462, 18),
#  ('6512bd', datetime.date(2019, 2, 1), 19.96807463798837, 19),
#  ('6512bd', datetime.date(2017, 3, 1), 19.2435823927125, 20),
#  ('6512bd', datetime.date(2018, 7, 1), 18.962901938451182, 21),
#  ('6512bd', datetime.date(2017, 5, 1), 18.642592196415322, 22),
#  ('6512bd', datetime.date(2018, 4, 1), 18.459614531461995, 23),
#  ('6512bd', datetime.date(2018, 6, 1), 17.696717093334257, 24),
#  ('6512bd', datetime.date(2018, 1, 1), 17.46848029811357, 25),
#  ('6512bd', datetime.date(2017, 1, 1), 17.06229255104265, 26),
#  ('6512bd', datetime.date(2021, 2, 1), 16.99278796551404, 27),
#  ('6512bd', datetime.date(2017, 4, 1), 16.23856144592821, 28),
#  ('6512bd', datetime.date(2017, 12, 1), 15.894195129301611, 29),
#  ('6512bd', datetime.date(2021, 8, 1), 15.86724519709179, 30),
#  ('6512bd', datetime.date(2021, 3, 1), 15.833648410761006, 31),
#  ('6512bd', datetime.date(2021, 5, 1), 14.636014208711755, 32),
#  ('6512bd', datetime.date(2019, 10, 1), 14.47405320568702, 33),
#  ('6512bd', datetime.date(2018, 9, 1), 14.18681918957688, 34),
#  ('6512bd', datetime.date(2020, 9, 1), 14.12228654849439, 35),
#  ('6512bd', datetime.date(2017, 10, 1), 14.034484389405268, 36),
#  ('6512bd', datetime.date(2020, 2, 1), 13.727518214224123, 37),
#  ('6512bd', datetime.date(2021, 4, 1), 12.92752254369727, 38),
#  ('6512bd', datetime.date(2021, 6, 1), 12.245527506278052, 39),
#  ('6512bd', datetime.date(2017, 8, 1), 10.973601495335462, 40),
#  ('6512bd', datetime.date(2019, 11, 1), 10.804015838021602, 41),
#  ('6512bd', datetime.date(2018, 8, 1), 9.748626328904995, 42),
#  ('6512bd', datetime.date(2019, 6, 1), 9.08546448337905, 43),
#  ('6512bd', datetime.date(2017, 7, 1), 8.98965724096325, 44),
#  ('6512bd', datetime.date(2019, 4, 1), 8.83943151961084, 45),
#  ('6512bd', datetime.date(2019, 8, 1), 8.79003445489829, 46),
#  ('6512bd', datetime.date(2019, 9, 1), 8.67331258161996, 47),
#  ('6512bd', datetime.date(2017, 6, 1), 8.137439163004464, 48),
#  ('6512bd', datetime.date(2020, 12, 1), 7.0650276234117335, 49),
#  ('6512bd', datetime.date(2020, 11, 1), 6.84741720934671, 50),
#  ('6512bd', datetime.date(2020, 4, 1), 6.32499041452313, 51),
#  ('6512bd', datetime.date(2017, 11, 1), 5.642016969779, 52),
#  ('6512bd', datetime.date(2019, 12, 1), 4.85340070542311, 53),
#  ('6512bd', datetime.date(2020, 3, 1), 3.27929272854593, 54),
#  ('6512bd', datetime.date(2020, 7, 1), 3.093949091057309, 55),
#  ('8f14e4', datetime.date(2017, 7, 1), 36.173837436812306, 1),
#  ('8f14e4', datetime.date(2019, 4, 1), 32.98201542169377, 2),
#  ('8f14e4', datetime.date(2017, 4, 1), 26.440014415008452, 3),
#  ('8f14e4', datetime.date(2018, 9, 1), 26.23127183999298, 4),
#  ('8f14e4', datetime.date(2021, 3, 1), 26.081332104297843, 5),
#  ('8f14e4', datetime.date(2019, 10, 1), 25.82132333430306, 6),
#  ('8f14e4', datetime.date(2018, 12, 1), 24.913225311370336, 7),
#  ('8f14e4', datetime.date(2019, 12, 1), 24.359340565543413, 8),
#  ('8f14e4', datetime.date(2021, 8, 1), 23.735739713156125, 9),
#  ('8f14e4', datetime.date(2020, 2, 1), 20.61955759081808, 10),
#  ('8f14e4', datetime.date(2021, 5, 1), 20.59622328592735, 11),
#  ('8f14e4', datetime.date(2018, 4, 1), 19.72565431586809, 12),
#  ('8f14e4', datetime.date(2019, 1, 1), 19.49705431131502, 13),
#  ('8f14e4', datetime.date(2017, 8, 1), 19.0357375024514, 14),
#  ('8f14e4', datetime.date(2019, 6, 1), 18.27102488960665, 15),
#  ('8f14e4', datetime.date(2018, 2, 1), 17.363075085385262, 16),
#  ('8f14e4', datetime.date(2020, 5, 1), 17.24389024152781, 17),
#  ('8f14e4', datetime.date(2021, 4, 1), 16.9593049926192, 18),
#  ('8f14e4', datetime.date(2018, 3, 1), 16.688655752577578, 19),
#  ('8f14e4', datetime.date(2018, 5, 1), 16.29882511693971, 20),
#  ('8f14e4', datetime.date(2017, 1, 1), 15.473702553167923, 21),
#  ('8f14e4', datetime.date(2018, 6, 1), 15.039958318534769, 22),
#  ('8f14e4', datetime.date(2020, 1, 1), 13.19241066554859, 23),
#  ('8f14e4', datetime.date(2020, 3, 1), 13.13253968288968, 24),
#  ('8f14e4', datetime.date(2019, 2, 1), 11.954429069130047, 25),
#  ('8f14e4', datetime.date(2019, 8, 1), 10.238399949364307, 26),
#  ('8f14e4', datetime.date(2019, 7, 1), 9.92011437155444, 27),
#  ('8f14e4', datetime.date(2017, 12, 1), 9.90434338785253, 28),
#  ('8f14e4', datetime.date(2017, 2, 1), 9.26845045945296, 29),
#  ('8f14e4', datetime.date(2020, 6, 1), 8.44559705664658, 30),
#  ('8f14e4', datetime.date(2020, 10, 1), 8.147825180558359, 31),
#  ('8f14e4', datetime.date(2018, 1, 1), 7.859181397570901, 32),
#  ('8f14e4', datetime.date(2018, 10, 1), 7.85301443719813, 33),
#  ('8f14e4', datetime.date(2017, 11, 1), 7.69410988515855, 34),
#  ('8f14e4', datetime.date(2021, 6, 1), 7.33400503862054, 35),
#  ('8f14e4', datetime.date(2019, 11, 1), 7.01598165835733, 36),
#  ('8f14e4', datetime.date(2018, 8, 1), 6.44330961652312, 37),
#  ('8f14e4', datetime.date(2017, 5, 1), 6.0020317716605796, 38),
#  ('8f14e4', datetime.date(2017, 3, 1), 5.99659115629436, 39),
#  ('8f14e4', datetime.date(2021, 1, 1), 5.61635884897352, 40),
#  ('8f14e4', datetime.date(2017, 10, 1), 5.49059493908, 41),
#  ('8f14e4', datetime.date(2019, 3, 1), 5.40447277529392, 42),
#  ('8f14e4', datetime.date(2018, 7, 1), 3.91258678026087, 43),
#  ('8f14e4', datetime.date(2017, 9, 1), 3.10106528013538, 44),
#  ('8f14e4', datetime.date(2020, 12, 1), 3.07584219593895, 45),
#  ('8f14e4', datetime.date(2017, 6, 1), 2.80893657297764, 46),
#  ('8f14e4', datetime.date(2021, 7, 1), 1.97763204531409, 47),
#  ('8f14e4', datetime.date(2020, 9, 1), 1.5581827258527912, 48),
#  ('8f14e4', datetime.date(2019, 9, 1), 0.884655042792453, 49),
#  ('a87ff6', datetime.date(2020, 7, 1), 27.28919836842423, 1),
#  ('a87ff6', datetime.date(2018, 7, 1), 24.68225160143227, 2),
#  ('a87ff6', datetime.date(2017, 7, 1), 18.40262393625405, 3),
#  ('a87ff6', datetime.date(2018, 11, 1), 14.69651722554168, 4),
#  ('a87ff6', datetime.date(2020, 10, 1), 13.939169841803292, 5),
#  ('a87ff6', datetime.date(2021, 7, 1), 13.691446371262929, 6),
#  ('a87ff6', datetime.date(2017, 9, 1), 12.906459877493223, 7),
#  ('a87ff6', datetime.date(2021, 1, 1), 12.63819787659564, 8),
#  ('a87ff6', datetime.date(2020, 4, 1), 11.935043409364754, 9),
#  ('a87ff6', datetime.date(2020, 5, 1), 11.91426882334262, 10),
#  ('a87ff6', datetime.date(2018, 6, 1), 11.13626422781806, 11),
#  ('a87ff6', datetime.date(2018, 12, 1), 10.143078173083813, 12),
#  ('a87ff6', datetime.date(2020, 2, 1), 9.683359262749178, 13),
#  ('a87ff6', datetime.date(2018, 4, 1), 8.34615210191146, 14),
#  ('a87ff6', datetime.date(2017, 12, 1), 8.02248497757017, 15),
#  ('a87ff6', datetime.date(2020, 3, 1), 8.01814649338031, 16),
#  ('a87ff6', datetime.date(2020, 6, 1), 7.91320035966077, 17),
#  ('a87ff6', datetime.date(2021, 8, 1), 7.553111106451031, 18),
#  ('a87ff6', datetime.date(2021, 4, 1), 7.35710855443987, 19),
#  ('a87ff6', datetime.date(2019, 9, 1), 7.3355489087761, 20),
#  ('a87ff6', datetime.date(2019, 12, 1), 7.16847899990587, 21),
#  ('a87ff6', datetime.date(2018, 5, 1), 7.1069460333484, 22),
#  ('a87ff6', datetime.date(2017, 3, 1), 7.063279295041838, 23),
#  ('a87ff6', datetime.date(2017, 2, 1), 6.87960502411055, 24),
#  ('a87ff6', datetime.date(2020, 1, 1), 5.45263351200195, 25),
#  ('a87ff6', datetime.date(2019, 7, 1), 5.28402661537339, 26),
#  ('a87ff6', datetime.date(2018, 9, 1), 5.06018920425699, 27),
#  ('a87ff6', datetime.date(2017, 8, 1), 4.87128285641898, 28),
#  ('a87ff6', datetime.date(2019, 8, 1), 4.62683396421898, 29),
#  ('a87ff6', datetime.date(2018, 1, 1), 3.820241265083409, 30),
#  ('a87ff6', datetime.date(2021, 3, 1), 3.07922321952329, 31),
#  ('a87ff6', datetime.date(2019, 3, 1), 2.75781446265231, 32),
#  ('a87ff6', datetime.date(2019, 5, 1), 2.234130483209713, 33),
#  ('a87ff6', datetime.date(2021, 6, 1), 2.21258594483668, 34),
#  ('a87ff6', datetime.date(2019, 11, 1), 1.48900751476059, 35),
#  ('a87ff6', datetime.date(2019, 10, 1), 0.676200720321454, 36),
#  ('a87ff6', datetime.date(2017, 5, 1), 0.65751712617331, 37),
#  ('a87ff6', datetime.date(2017, 4, 1), 0.107008112859539, 38),
#  ('aab323', datetime.date(2018, 9, 1), 41.175076337098375, 1),
#  ('aab323', datetime.date(2017, 1, 1), 39.47349701408168, 2),
#  ('aab323', datetime.date(2017, 7, 1), 33.94771805041057, 3),
#  ('aab323', datetime.date(2018, 7, 1), 29.76291942659762, 4),
#  ('aab323', datetime.date(2021, 8, 1), 29.7325821019226, 5),
#  ('aab323', datetime.date(2017, 3, 1), 27.664629947653268, 6),
#  ('aab323', datetime.date(2019, 2, 1), 27.543382313317082, 7),
#  ('aab323', datetime.date(2019, 4, 1), 27.0764240073932, 8),
#  ('aab323', datetime.date(2018, 11, 1), 26.55365451852827, 9),
#  ('aab323', datetime.date(2020, 4, 1), 25.044103031141493, 10),
#  ('aab323', datetime.date(2021, 6, 1), 22.89930590386862, 11),
#  ('aab323', datetime.date(2019, 3, 1), 22.78806303276831, 12),
#  ('aab323', datetime.date(2017, 6, 1), 20.88331568313727, 13),
#  ('aab323', datetime.date(2018, 10, 1), 19.348934469204263, 14),
#  ('aab323', datetime.date(2017, 5, 1), 18.459339615720218, 15),
#  ('aab323', datetime.date(2018, 12, 1), 17.78070408136354, 16),
#  ('aab323', datetime.date(2019, 1, 1), 17.66139983259144, 17),
#  ('aab323', datetime.date(2019, 6, 1), 17.59229162209284, 18),
#  ('aab323', datetime.date(2020, 2, 1), 17.0741848601639, 19),
#  ('aab323', datetime.date(2018, 8, 1), 16.89246576685399, 20),
#  ('aab323', datetime.date(2020, 10, 1), 16.78883822195882, 21),
#  ('aab323', datetime.date(2017, 2, 1), 16.51823894504173, 22),
#  ('aab323', datetime.date(2017, 11, 1), 16.32124209557812, 23),
#  ('aab323', datetime.date(2018, 6, 1), 16.27732616442425, 24),
#  ('aab323', datetime.date(2021, 3, 1), 15.41390162316645, 25),
#  ('aab323', datetime.date(2019, 12, 1), 14.720710376309537, 26),
#  ('aab323', datetime.date(2020, 9, 1), 13.919988909330092, 27),
#  ('aab323', datetime.date(2018, 4, 1), 13.78330795114941, 28),
#  ('aab323', datetime.date(2021, 5, 1), 13.290113333062589, 29),
#  ('aab323', datetime.date(2021, 7, 1), 13.016007467448567, 30),
#  ('aab323', datetime.date(2018, 2, 1), 12.74832940630574, 31),
#  ('aab323', datetime.date(2019, 11, 1), 12.328952185920354, 32),
#  ('aab323', datetime.date(2020, 11, 1), 11.505773523008644, 33),
#  ('aab323', datetime.date(2018, 1, 1), 11.29040690605522, 34),
#  ('aab323', datetime.date(2017, 12, 1), 11.23069333482895, 35),
#  ('aab323', datetime.date(2018, 3, 1), 11.00921837848283, 36),
#  ('aab323', datetime.date(2019, 9, 1), 10.623769959878434, 37),
#  ('aab323', datetime.date(2019, 10, 1), 10.562094472345334, 38),
#  ('aab323', datetime.date(2021, 1, 1), 10.53224431876984, 39),
#  ('aab323', datetime.date(2020, 1, 1), 9.16680008475425, 40),
#  ('aab323', datetime.date(2019, 5, 1), 9.07594116074737, 41),
#  ('aab323', datetime.date(2020, 3, 1), 8.90372927076375, 42),
#  ('aab323', datetime.date(2020, 12, 1), 6.1137000743281105, 43),
#  ('aab323', datetime.date(2019, 7, 1), 5.73262291005204, 44),
#  ('aab323', datetime.date(2021, 2, 1), 4.78565399257196, 45),
#  ('aab323', datetime.date(2017, 4, 1), 4.39482563836808, 46),
#  ('aab323', datetime.date(2017, 9, 1), 4.277223351738973, 47),
#  ('aab323', datetime.date(2018, 5, 1), 3.16207157443021, 48),
#  ('aab323', datetime.date(2020, 6, 1), 2.97890195196029, 49),
#  ('aab323', datetime.date(2021, 4, 1), 1.550898538132587, 50),
#  ('c20ad4', datetime.date(2017, 12, 1), 37.71908498970638, 1),
#  ('c20ad4', datetime.date(2019, 7, 1), 37.05139368127192, 2),
#  ('c20ad4', datetime.date(2019, 5, 1), 35.61213186606214, 3),
#  ('c20ad4', datetime.date(2020, 12, 1), 34.68578126484835, 4),
#  ('c20ad4', datetime.date(2021, 4, 1), 25.10586511397989, 5),
#  ('c20ad4', datetime.date(2017, 11, 1), 23.118900688280892, 6),
#  ('c20ad4', datetime.date(2017, 5, 1), 22.883412308573988, 7),
#  ('c20ad4', datetime.date(2020, 3, 1), 22.24554908546434, 8),
#  ('c20ad4', datetime.date(2018, 2, 1), 21.62297035820071, 9),
#  ('c20ad4', datetime.date(2021, 5, 1), 19.335305904923352, 10),
#  ('c20ad4', datetime.date(2021, 8, 1), 16.7947185595743, 11),
#  ('c20ad4', datetime.date(2018, 8, 1), 16.54356398054205, 12),
#  ('c20ad4', datetime.date(2020, 1, 1), 14.74578779806091, 13),
#  ('c20ad4', datetime.date(2020, 2, 1), 14.631997114074338, 14),
#  ('c20ad4', datetime.date(2020, 6, 1), 14.286433404557389, 15),
#  ('c20ad4', datetime.date(2018, 6, 1), 14.11016395685117, 16),
#  ('c20ad4', datetime.date(2018, 10, 1), 13.500538566240719, 17),
#  ('c20ad4', datetime.date(2020, 10, 1), 12.461125659067914, 18),
#  ('c20ad4', datetime.date(2019, 2, 1), 11.825238352192429, 19),
#  ('c20ad4', datetime.date(2018, 4, 1), 11.690323990230201, 20),
#  ('c20ad4', datetime.date(2018, 12, 1), 11.67537271242004, 21),
#  ('c20ad4', datetime.date(2020, 8, 1), 11.58090672240689, 22),
#  ('c20ad4', datetime.date(2021, 1, 1), 11.07204773187146, 23),
#  ('c20ad4', datetime.date(2019, 10, 1), 10.92538948873873, 24),
#  ('c20ad4', datetime.date(2017, 1, 1), 10.759211968392563, 25),
#  ('c20ad4', datetime.date(2017, 10, 1), 10.19492335796784, 26),
#  ('c20ad4', datetime.date(2021, 6, 1), 9.685213882989814, 27),
#  ('c20ad4', datetime.date(2018, 5, 1), 9.504356014707511, 28),
#  ('c20ad4', datetime.date(2018, 1, 1), 9.492243370512515, 29),
#  ('c20ad4', datetime.date(2018, 11, 1), 9.42951564584262, 30),
#  ('c20ad4', datetime.date(2017, 8, 1), 8.78870151772152, 31),
#  ('c20ad4', datetime.date(2017, 7, 1), 8.76248698861684, 32),
#  ('c20ad4', datetime.date(2017, 2, 1), 8.63376505693146, 33),
#  ('c20ad4', datetime.date(2018, 7, 1), 7.74015025114579, 34),
#  ('c20ad4', datetime.date(2017, 4, 1), 7.62836823458994, 35),
#  ('c20ad4', datetime.date(2020, 4, 1), 7.203714094701541, 36),
#  ('c20ad4', datetime.date(2021, 7, 1), 6.97586419768804, 37),
#  ('c20ad4', datetime.date(2019, 4, 1), 6.28555909532562, 38),
#  ('c20ad4', datetime.date(2017, 3, 1), 5.6549947394064, 39),
#  ('c20ad4', datetime.date(2021, 3, 1), 5.54408099430237, 40),
#  ('c20ad4', datetime.date(2020, 5, 1), 3.48381092245617, 41),
#  ('c20ad4', datetime.date(2018, 3, 1), 3.369518676852114, 42),
#  ('c20ad4', datetime.date(2019, 8, 1), 2.99410238914231, 43),
#  ('c20ad4', datetime.date(2019, 11, 1), 1.83028422914095, 44),
#  ('c20ad4', datetime.date(2020, 9, 1), 0.862192154833643, 45),
#  ('c4ca42', datetime.date(2021, 4, 1), 40.11347472402257, 1),
#  ('c4ca42', datetime.date(2021, 1, 1), 38.96835933682823, 2),
#  ('c4ca42', datetime.date(2020, 6, 1), 37.33866389102275, 3),
#  ('c4ca42', datetime.date(2019, 8, 1), 36.548709114174926, 4),
#  ('c4ca42', datetime.date(2019, 7, 1), 35.33731074054451, 5),
#  ('c4ca42', datetime.date(2018, 11, 1), 34.877381137356984, 6),
#  ('c4ca42', datetime.date(2017, 10, 1), 34.32341413897536, 7),
#  ('c4ca42', datetime.date(2018, 3, 1), 31.137413173947202, 8),
#  ('c4ca42', datetime.date(2020, 5, 1), 30.55511401744916, 9),
#  ('c4ca42', datetime.date(2019, 4, 1), 30.18089221549547, 10),
#  ('c4ca42', datetime.date(2018, 12, 1), 29.684217948447472, 11),
#  ('c4ca42', datetime.date(2019, 9, 1), 28.380671811113587, 12),
#  ('c4ca42', datetime.date(2019, 10, 1), 27.757232243587993, 13),
#  ('c4ca42', datetime.date(2020, 8, 1), 27.0304451135249, 14),
#  ('c4ca42', datetime.date(2020, 12, 1), 26.769881821015293, 15),
#  ('c4ca42', datetime.date(2019, 6, 1), 26.15634298382638, 16),
#  ('c4ca42', datetime.date(2021, 5, 1), 26.07849209543488, 17),
#  ('c4ca42', datetime.date(2020, 7, 1), 25.667870449461457, 18),
#  ('c4ca42', datetime.date(2018, 2, 1), 23.98524960131866, 19),
#  ('c4ca42', datetime.date(2020, 4, 1), 23.976234082634303, 20),
#  ('c4ca42', datetime.date(2017, 3, 1), 23.27122050962974, 21),
#  ('c4ca42', datetime.date(2017, 11, 1), 21.74608312774455, 22),
#  ('c4ca42', datetime.date(2017, 5, 1), 20.30794989148567, 23),
#  ('c4ca42', datetime.date(2020, 3, 1), 20.26496058050874, 24),
#  ('c4ca42', datetime.date(2017, 6, 1), 20.0312153880234, 25),
#  ('c4ca42', datetime.date(2019, 11, 1), 18.6352403124938, 26),
#  ('c4ca42', datetime.date(2017, 7, 1), 18.18750361271857, 27),
#  ('c4ca42', datetime.date(2018, 8, 1), 17.149277565640418, 28),
#  ('c4ca42', datetime.date(2021, 3, 1), 16.559597906824727, 29),
#  ('c4ca42', datetime.date(2017, 4, 1), 16.40592137665834, 30),
#  ('c4ca42', datetime.date(2019, 2, 1), 15.65361584544295, 31),
#  ('c4ca42', datetime.date(2018, 10, 1), 15.33531731959161, 32),
#  ('c4ca42', datetime.date(2020, 1, 1), 15.156874937380529, 33),
#  ('c4ca42', datetime.date(2021, 2, 1), 13.96900756974126, 34),
#  ('c4ca42', datetime.date(2017, 9, 1), 12.43937642113302, 35),
#  ('c4ca42', datetime.date(2021, 8, 1), 10.42104636018657, 36),
#  ('c4ca42', datetime.date(2017, 8, 1), 10.21030771785412, 37),
#  ('c4ca42', datetime.date(2019, 12, 1), 8.80248638010783, 38),
#  ('c4ca42', datetime.date(2021, 6, 1), 8.62127370302655, 39),
#  ('c4ca42', datetime.date(2020, 10, 1), 8.499714878949867, 40),
#  ('c4ca42', datetime.date(2019, 1, 1), 8.2221462041257, 41),
#  ('c4ca42', datetime.date(2018, 9, 1), 8.13736930268615, 42),
#  ('c4ca42', datetime.date(2017, 2, 1), 7.660920258357821, 43),
#  ('c4ca42', datetime.date(2020, 9, 1), 7.62169664606148, 44),
#  ('c4ca42', datetime.date(2018, 7, 1), 7.57518787958342, 45),
#  ('c4ca42', datetime.date(2018, 5, 1), 7.321932974270309, 46),
#  ('c4ca42', datetime.date(2020, 2, 1), 7.020880145599548, 47),
#  ('c4ca42', datetime.date(2018, 6, 1), 6.86244843540106, 48),
#  ('c4ca42', datetime.date(2021, 7, 1), 6.85262045206976, 49),
#  ('c4ca42', datetime.date(2019, 3, 1), 6.48638244472003, 50),
#  ('c4ca42', datetime.date(2017, 12, 1), 5.48648746426753, 51),
#  ('c4ca42', datetime.date(2018, 4, 1), 4.33243957496831, 52),
#  ('c4ca42', datetime.date(2018, 1, 1), 1.44605756992267, 53),
#  ('c51ce4', datetime.date(2017, 5, 1), 66.09244042953502, 1),
#  ('c51ce4', datetime.date(2020, 11, 1), 41.03488692527595, 2),
#  ('c51ce4', datetime.date(2017, 7, 1), 39.591781007582924, 3),
#  ('c51ce4', datetime.date(2019, 3, 1), 38.779061040423166, 4),
#  ('c51ce4', datetime.date(2017, 3, 1), 35.21695685399591, 5),
#  ('c51ce4', datetime.date(2020, 6, 1), 33.97186187801526, 6),
#  ('c51ce4', datetime.date(2017, 2, 1), 33.12622618065384, 7),
#  ('c51ce4', datetime.date(2019, 7, 1), 32.75749453985203, 8),
#  ('c51ce4', datetime.date(2017, 12, 1), 31.01398048810377, 9),
#  ('c51ce4', datetime.date(2018, 2, 1), 30.94054344281307, 10),
#  ('c51ce4', datetime.date(2018, 10, 1), 30.283323121315572, 11),
#  ('c51ce4', datetime.date(2017, 11, 1), 29.896287257400243, 12),
#  ('c51ce4', datetime.date(2018, 9, 1), 28.064991074606237, 13),
#  ('c51ce4', datetime.date(2021, 2, 1), 27.286492678312968, 14),
#  ('c51ce4', datetime.date(2020, 4, 1), 26.23758634953717, 15),
#  ('c51ce4', datetime.date(2021, 6, 1), 25.90970066920371, 16),
#  ('c51ce4', datetime.date(2018, 4, 1), 25.2252107649905, 17),
#  ('c51ce4', datetime.date(2019, 6, 1), 24.31199362219189, 18),
#  ('c51ce4', datetime.date(2019, 12, 1), 22.65980011064422, 19),
#  ('c51ce4', datetime.date(2018, 7, 1), 22.35499262708604, 20),
#  ('c51ce4', datetime.date(2021, 4, 1), 21.63505371224847, 21),
#  ('c51ce4', datetime.date(2018, 3, 1), 21.538140431525893, 22),
#  ('c51ce4', datetime.date(2017, 6, 1), 21.31279024009459, 23),
#  ('c51ce4', datetime.date(2019, 11, 1), 19.216653770281987, 24),
#  ('c51ce4', datetime.date(2020, 8, 1), 19.03219836055566, 25),
#  ('c51ce4', datetime.date(2019, 5, 1), 18.9492655413371, 26),
#  ('c51ce4', datetime.date(2020, 3, 1), 18.09447164961139, 27),
#  ('c51ce4', datetime.date(2020, 5, 1), 17.974822230438498, 28),
#  ('c51ce4', datetime.date(2021, 3, 1), 17.86328460821163, 29),
#  ('c51ce4', datetime.date(2019, 10, 1), 17.63091758108981, 30),
#  ('c51ce4', datetime.date(2020, 10, 1), 16.19770342101744, 31),
#  ('c51ce4', datetime.date(2021, 5, 1), 15.69208343965482, 32),
#  ('c51ce4', datetime.date(2019, 9, 1), 14.586236336271309, 33),
#  ('c51ce4', datetime.date(2020, 2, 1), 13.954691216489051, 34),
#  ('c51ce4', datetime.date(2021, 7, 1), 13.289547597775533, 35),
#  ('c51ce4', datetime.date(2018, 12, 1), 12.703748156763872, 36),
#  ('c51ce4', datetime.date(2020, 9, 1), 12.12017681000255, 37),
#  ('c51ce4', datetime.date(2021, 8, 1), 11.704320305587363, 38),
#  ('c51ce4', datetime.date(2018, 6, 1), 11.44537356606535, 39),
#  ('c51ce4', datetime.date(2017, 10, 1), 11.3428390444562, 40),
#  ('c51ce4', datetime.date(2019, 8, 1), 11.09805168341566, 41),
#  ('c51ce4', datetime.date(2019, 4, 1), 11.078691347961112, 42),
#  ('c51ce4', datetime.date(2020, 12, 1), 10.772604932567159, 43),
#  ('c51ce4', datetime.date(2019, 1, 1), 10.21496333697613, 44),
#  ('c51ce4', datetime.date(2018, 5, 1), 9.41160711253705, 45),
#  ('c51ce4', datetime.date(2018, 8, 1), 9.17344484388053, 46),
#  ('c51ce4', datetime.date(2017, 1, 1), 8.88989067836274, 47),
#  ('c51ce4', datetime.date(2018, 11, 1), 7.74812065880727, 48),
#  ('c51ce4', datetime.date(2021, 1, 1), 7.06769787529801, 49),
#  ('c51ce4', datetime.date(2017, 8, 1), 5.0984123914673, 50),
#  ('c51ce4', datetime.date(2017, 4, 1), 5.09729532018962, 51),
#  ('c51ce4', datetime.date(2020, 1, 1), 3.50667842756611, 52),
#  ('c51ce4', datetime.date(2020, 7, 1), 2.720417819370804, 53),
#  ('c51ce4', datetime.date(2017, 9, 1), 1.91725524178683, 54),
#  ('c51ce4', datetime.date(2019, 2, 1), 1.24441794942808, 55),
#  ('c51ce4', datetime.date(2018, 1, 1), 0.621103868915149, 56),
#  ('c81e72', datetime.date(2018, 8, 1), 41.26728177476413, 1),
#  ('c81e72', datetime.date(2020, 11, 1), 39.97032300398888, 2),
#  ('c81e72', datetime.date(2019, 5, 1), 33.142877116280765, 3),
#  ('c81e72', datetime.date(2017, 10, 1), 31.513429043972792, 4),
#  ('c81e72', datetime.date(2018, 4, 1), 27.1542949764601, 5),
#  ('c81e72', datetime.date(2020, 12, 1), 25.79039478868645, 6),
#  ('c81e72', datetime.date(2021, 5, 1), 24.803306546913827, 7),
#  ('c81e72', datetime.date(2019, 9, 1), 24.196847599809892, 8),
#  ('c81e72', datetime.date(2020, 8, 1), 23.88337606536133, 9),
#  ('c81e72', datetime.date(2017, 2, 1), 23.79620742626604, 10),
#  ('c81e72', datetime.date(2017, 6, 1), 23.702437755327527, 11),
#  ('c81e72', datetime.date(2018, 1, 1), 22.581857447038722, 12),
#  ('c81e72', datetime.date(2021, 7, 1), 20.76069752546424, 13),
#  ('c81e72', datetime.date(2018, 2, 1), 20.47639158747647, 14),
#  ('c81e72', datetime.date(2018, 7, 1), 19.016576352114996, 15),
#  ('c81e72', datetime.date(2020, 2, 1), 18.14210951328605, 16),
#  ('c81e72', datetime.date(2020, 6, 1), 16.901164995577112, 17),
#  ('c81e72', datetime.date(2018, 11, 1), 16.8449988964142, 18),
#  ('c81e72', datetime.date(2017, 3, 1), 16.04529182886352, 19),
#  ('c81e72', datetime.date(2021, 3, 1), 15.65066694084144, 20),
#  ('c81e72', datetime.date(2021, 4, 1), 14.66041962881636, 21),
#  ('c81e72', datetime.date(2020, 1, 1), 14.530930720097793, 22),
#  ('c81e72', datetime.date(2021, 6, 1), 14.34295696785312, 23),
#  ('c81e72', datetime.date(2018, 9, 1), 14.05099213455383, 24),
#  ('c81e72', datetime.date(2019, 3, 1), 13.58844283138048, 25),
#  ('c81e72', datetime.date(2017, 11, 1), 13.47043114612752, 26),
#  ('c81e72', datetime.date(2019, 6, 1), 13.349469909596865, 27),
#  ('c81e72', datetime.date(2019, 11, 1), 12.632168742542335, 28),
#  ('c81e72', datetime.date(2017, 5, 1), 12.594824407918033, 29),
#  ('c81e72', datetime.date(2019, 10, 1), 11.43827475167015, 30),
#  ('c81e72', datetime.date(2017, 4, 1), 10.845703934354175, 31),
#  ('c81e72', datetime.date(2020, 3, 1), 9.87878650506665, 32),
#  ('c81e72', datetime.date(2019, 8, 1), 9.00125184651451, 33),
#  ('c81e72', datetime.date(2017, 12, 1), 8.800373565063603, 34),
#  ('c81e72', datetime.date(2020, 10, 1), 8.77678753657442, 35),
#  ('c81e72', datetime.date(2021, 8, 1), 8.54203274852821, 36),
#  ('c81e72', datetime.date(2017, 9, 1), 8.15119994222546, 37),
#  ('c81e72', datetime.date(2018, 3, 1), 8.11760900473761, 38),
#  ('c81e72', datetime.date(2017, 1, 1), 7.556360380275319, 39),
#  ('c81e72', datetime.date(2019, 1, 1), 5.94299595498011, 40),
#  ('c81e72', datetime.date(2018, 10, 1), 5.41580324172134, 41),
#  ('c81e72', datetime.date(2018, 6, 1), 5.25827463304996, 42),
#  ('c81e72', datetime.date(2021, 2, 1), 4.30844494855275, 43),
#  ('c81e72', datetime.date(2021, 1, 1), 2.76886034277581, 44),
#  ('c81e72', datetime.date(2019, 12, 1), 2.24799013419723, 45),
#  ('c81e72', datetime.date(2020, 5, 1), 2.14000901370898, 46),
#  ('c81e72', datetime.date(2019, 2, 1), 1.36879108817961, 47),
#  ('c9f0f8', datetime.date(2020, 11, 1), 15.931855129247868, 1),
#  ('c9f0f8', datetime.date(2017, 7, 1), 13.82981725504329, 2),
#  ('c9f0f8', datetime.date(2020, 12, 1), 13.58551771497946, 3),
#  ('c9f0f8', datetime.date(2017, 2, 1), 13.425144311376009, 4),
#  ('c9f0f8', datetime.date(2019, 9, 1), 12.419821123301563, 5),
#  ('c9f0f8', datetime.date(2018, 10, 1), 10.56057661186394, 6),
#  ('c9f0f8', datetime.date(2019, 7, 1), 10.50608760135525, 7),
#  ('c9f0f8', datetime.date(2019, 2, 1), 10.254739160156984, 8),
#  ('c9f0f8', datetime.date(2018, 2, 1), 9.79513788657624, 9),
#  ('c9f0f8', datetime.date(2017, 1, 1), 9.51184667559968, 10),
#  ('c9f0f8', datetime.date(2018, 11, 1), 9.08848636725484, 11),
#  ('c9f0f8', datetime.date(2018, 8, 1), 8.85105272521407, 12),
#  ('c9f0f8', datetime.date(2019, 4, 1), 8.75176173898101, 13),
#  ('c9f0f8', datetime.date(2020, 9, 1), 8.35989122722591, 14),
#  ('c9f0f8', datetime.date(2017, 6, 1), 8.06744184283861, 15),
#  ('c9f0f8', datetime.date(2020, 8, 1), 7.87041786932317, 16),
#  ('c9f0f8', datetime.date(2020, 5, 1), 7.2526109522887, 17),
#  ('c9f0f8', datetime.date(2018, 5, 1), 6.64178261383636, 18),
#  ('c9f0f8', datetime.date(2021, 2, 1), 6.60726295695863, 19),
#  ('c9f0f8', datetime.date(2017, 10, 1), 6.52576729190972, 20),
#  ('c9f0f8', datetime.date(2019, 6, 1), 6.50463111179835, 21),
#  ('c9f0f8', datetime.date(2020, 1, 1), 6.37381403703973, 22),
#  ('c9f0f8', datetime.date(2018, 6, 1), 5.7679547416549, 23),
#  ('c9f0f8', datetime.date(2020, 3, 1), 5.15217090289159, 24),
#  ('c9f0f8', datetime.date(2019, 12, 1), 4.96116189724052, 25),
#  ('c9f0f8', datetime.date(2018, 1, 1), 4.93015123654875, 26),
#  ('c9f0f8', datetime.date(2019, 5, 1), 4.29315803666125, 27),
#  ('c9f0f8', datetime.date(2017, 3, 1), 3.72299432582377, 28),
#  ('c9f0f8', datetime.date(2019, 8, 1), 3.6898558460987, 29),
#  ('c9f0f8', datetime.date(2017, 12, 1), 2.94877665333001, 30),
#  ('c9f0f8', datetime.date(2019, 10, 1), 2.57892708875211, 31),
#  ('c9f0f8', datetime.date(2021, 5, 1), 2.46494374040726, 32),
#  ('c9f0f8', datetime.date(2018, 3, 1), 2.00502215802214, 33),
#  ('c9f0f8', datetime.date(2021, 4, 1), 0.970107679199153, 34),
#  ('c9f0f8', datetime.date(2017, 8, 1), 0.0664922409161406, 35),
#  ('d3d944', datetime.date(2020, 4, 1), 60.41736997398335, 1),
#  ('d3d944', datetime.date(2017, 12, 1), 44.68574636120401, 2),
#  ('d3d944', datetime.date(2018, 2, 1), 44.44951570587349, 3),
#  ('d3d944', datetime.date(2021, 4, 1), 37.22715374526999, 4),
#  ('d3d944', datetime.date(2021, 5, 1), 35.57567350763826, 5),
#  ('d3d944', datetime.date(2017, 1, 1), 35.25926894941347, 6),
#  ('d3d944', datetime.date(2020, 7, 1), 32.781212028689694, 7),
#  ('d3d944', datetime.date(2019, 10, 1), 31.969200613580252, 8),
#  ('d3d944', datetime.date(2018, 11, 1), 31.48953630796825, 9),
#  ('d3d944', datetime.date(2018, 12, 1), 29.48556313920622, 10),
#  ('d3d944', datetime.date(2017, 11, 1), 28.366762537905778, 11),
#  ('d3d944', datetime.date(2017, 4, 1), 26.905730809675717, 12),
#  ('d3d944', datetime.date(2018, 3, 1), 26.5465870351592, 13),
#  ('d3d944', datetime.date(2017, 8, 1), 26.5066926327476, 14),
#  ('d3d944', datetime.date(2019, 2, 1), 25.497825391652242, 15),
#  ('d3d944', datetime.date(2018, 5, 1), 25.430059141211945, 16),
#  ('d3d944', datetime.date(2021, 1, 1), 24.261411944260942, 17),
#  ('d3d944', datetime.date(2020, 9, 1), 22.759234891975883, 18),
#  ('d3d944', datetime.date(2019, 11, 1), 22.721196447216798, 19),
#  ('d3d944', datetime.date(2019, 9, 1), 22.264134721015473, 20),
#  ('d3d944', datetime.date(2021, 7, 1), 22.08602670011221, 21),
#  ('d3d944', datetime.date(2019, 12, 1), 21.925979694459556, 22),
#  ('d3d944', datetime.date(2020, 3, 1), 21.3056277669612, 23),
#  ('d3d944', datetime.date(2021, 3, 1), 19.698953103445547, 24),
#  ('d3d944', datetime.date(2017, 5, 1), 18.11553171653256, 25),
#  ('d3d944', datetime.date(2019, 7, 1), 18.004356354530657, 26),
#  ('d3d944', datetime.date(2020, 10, 1), 17.91093442794036, 27),
#  ('d3d944', datetime.date(2020, 11, 1), 17.55298192152717, 28),
#  ('d3d944', datetime.date(2017, 9, 1), 16.90402759703922, 29),
#  ('d3d944', datetime.date(2017, 10, 1), 16.54095778135364, 30),
#  ('d3d944', datetime.date(2019, 1, 1), 16.51077841644493, 31),
#  ('d3d944', datetime.date(2018, 8, 1), 16.1321223427873, 32),
#  ('d3d944', datetime.date(2017, 3, 1), 14.71621545019552, 33),
#  ('d3d944', datetime.date(2019, 8, 1), 14.322611453209081, 34),
#  ('d3d944', datetime.date(2020, 12, 1), 14.269292778807948, 35),
#  ('d3d944', datetime.date(2020, 8, 1), 13.414934500304268, 36),
#  ('d3d944', datetime.date(2021, 2, 1), 12.966434921687469, 37),
#  ('d3d944', datetime.date(2019, 3, 1), 12.378236321067211, 38),
#  ('d3d944', datetime.date(2020, 5, 1), 11.62286535825039, 39),
#  ('d3d944', datetime.date(2018, 7, 1), 11.186859860963171, 40),
#  ('d3d944', datetime.date(2017, 2, 1), 10.59776086454058, 41),
#  ('d3d944', datetime.date(2017, 6, 1), 9.82648410023096, 42),
#  ('d3d944', datetime.date(2019, 4, 1), 9.382544739664128, 43),
#  ('d3d944', datetime.date(2019, 5, 1), 9.078412666406031, 44),
#  ('d3d944', datetime.date(2018, 6, 1), 6.8637765742223005, 45),
#  ('d3d944', datetime.date(2021, 6, 1), 6.7778526361889, 46),
#  ('d3d944', datetime.date(2020, 2, 1), 6.615118262804531, 47),
#  ('d3d944', datetime.date(2020, 1, 1), 6.45960553683967, 48),
#  ('d3d944', datetime.date(2017, 7, 1), 6.42781786312685, 49),
#  ('d3d944', datetime.date(2018, 1, 1), 6.12523636659414, 50),
#  ('d3d944', datetime.date(2020, 6, 1), 5.17788337757427, 51),
#  ('d3d944', datetime.date(2021, 8, 1), 4.5299199948769, 52),
#  ('d3d944', datetime.date(2018, 4, 1), 4.04511158503798, 53),
#  ('d3d944', datetime.date(2018, 10, 1), 2.3331746254925143, 54),
#  ('d3d944', datetime.date(2018, 9, 1), 1.009659797986231, 55),
#  ('e4da3b', datetime.date(2019, 1, 1), 30.484426410776322, 1),
#  ('e4da3b', datetime.date(2020, 6, 1), 27.21791763813115, 2),
#  ('e4da3b', datetime.date(2019, 7, 1), 25.771432643538926, 3),
#  ('e4da3b', datetime.date(2018, 10, 1), 24.23866076846774, 4),
#  ('e4da3b', datetime.date(2021, 7, 1), 24.17401395086827, 5),
#  ('e4da3b', datetime.date(2018, 4, 1), 23.14602009825474, 6),
#  ('e4da3b', datetime.date(2017, 8, 1), 21.65454329898444, 7),
#  ('e4da3b', datetime.date(2020, 9, 1), 20.264045131905533, 8),
#  ('e4da3b', datetime.date(2017, 1, 1), 17.87531181867937, 9),
#  ('e4da3b', datetime.date(2019, 12, 1), 17.566884853127252, 10),
#  ('e4da3b', datetime.date(2017, 7, 1), 17.33174167875926, 11),
#  ('e4da3b', datetime.date(2017, 3, 1), 17.279564695029, 12),
#  ('e4da3b', datetime.date(2020, 2, 1), 16.695235791469397, 13),
#  ('e4da3b', datetime.date(2019, 6, 1), 16.54245080547896, 14),
#  ('e4da3b', datetime.date(2018, 9, 1), 16.0280865560388, 15),
#  ('e4da3b', datetime.date(2019, 4, 1), 15.776973212947608, 16),
#  ('e4da3b', datetime.date(2019, 5, 1), 15.20976768182215, 17),
#  ('e4da3b', datetime.date(2017, 6, 1), 14.77058986591355, 18),
#  ('e4da3b', datetime.date(2021, 1, 1), 14.210004206274402, 19),
#  ('e4da3b', datetime.date(2018, 8, 1), 14.06399071906133, 20),
#  ('e4da3b', datetime.date(2017, 11, 1), 12.56292252988047, 21),
#  ('e4da3b', datetime.date(2017, 5, 1), 11.66939974405629, 22),
#  ('e4da3b', datetime.date(2018, 12, 1), 11.52926446319072, 23),
#  ('e4da3b', datetime.date(2017, 4, 1), 10.26461282620332, 24),
#  ('e4da3b', datetime.date(2020, 12, 1), 9.54411844232069, 25),
#  ('e4da3b', datetime.date(2020, 11, 1), 9.206693856785261, 26),
#  ('e4da3b', datetime.date(2020, 3, 1), 8.90755836084036, 27),
#  ('e4da3b', datetime.date(2019, 9, 1), 8.84405302532603, 28),
#  ('e4da3b', datetime.date(2021, 3, 1), 8.59229760968475, 29),
#  ('e4da3b', datetime.date(2018, 6, 1), 8.443126954607326, 30),
#  ('e4da3b', datetime.date(2019, 3, 1), 8.33009315749301, 31),
#  ('e4da3b', datetime.date(2019, 11, 1), 7.83508409009854, 32),
#  ('e4da3b', datetime.date(2018, 2, 1), 6.81419189915686, 33),
#  ('e4da3b', datetime.date(2018, 7, 1), 6.7799458216999, 34),
#  ('e4da3b', datetime.date(2018, 3, 1), 6.70006787489196, 35),
#  ('e4da3b', datetime.date(2021, 5, 1), 6.52430043858072, 36),
#  ('e4da3b', datetime.date(2017, 12, 1), 6.46648336832168, 37),
#  ('e4da3b', datetime.date(2020, 10, 1), 6.38593051340383, 38),
#  ('e4da3b', datetime.date(2021, 6, 1), 6.17210775671911, 39),
#  ('e4da3b', datetime.date(2021, 2, 1), 5.958180613660137, 40),
#  ('e4da3b', datetime.date(2019, 8, 1), 5.626738860362156, 41),
#  ('e4da3b', datetime.date(2020, 7, 1), 4.35785773618193, 42),
#  ('e4da3b', datetime.date(2020, 1, 1), 3.41587742806059, 43),
#  ('e4da3b', datetime.date(2019, 10, 1), 2.62793588606804, 44),
#  ('e4da3b', datetime.date(2020, 8, 1), 1.99097403990525, 45),
#  ('e4da3b', datetime.date(2017, 9, 1), 1.55511146431071, 46),
#  ('e4da3b', datetime.date(2021, 4, 1), 1.18206682250847, 47),
#  ('e4da3b', datetime.date(2020, 5, 1), 1.11050262164444, 48),
#  ('e4da3b', datetime.date(2018, 11, 1), 0.770666788836394, 49),
#  ('e4da3b', datetime.date(2021, 8, 1), 0.652127734818357, 50),
#  ('e4da3b', datetime.date(2018, 5, 1), 0.590107557307071, 51),
#  ('eccbc8', datetime.date(2021, 3, 1), 36.485934922948275, 1),
#  ('eccbc8', datetime.date(2018, 10, 1), 28.228877553477886, 2),
#  ('eccbc8', datetime.date(2021, 1, 1), 26.350363731270825, 3),
#  ('eccbc8', datetime.date(2021, 5, 1), 26.28342828936884, 4),
#  ('eccbc8', datetime.date(2019, 7, 1), 24.99456531556838, 5),
#  ('eccbc8', datetime.date(2019, 1, 1), 24.74601634925051, 6),
#  ('eccbc8', datetime.date(2019, 11, 1), 24.17070273085219, 7),
#  ('eccbc8', datetime.date(2017, 1, 1), 23.901952710999375, 8),
#  ('eccbc8', datetime.date(2019, 6, 1), 23.49629242711352, 9),
#  ('eccbc8', datetime.date(2017, 10, 1), 22.46965956706361, 10),
#  ('eccbc8', datetime.date(2017, 12, 1), 21.30618601875295, 11),
#  ('eccbc8', datetime.date(2021, 8, 1), 20.976971265002717, 12),
#  ('eccbc8', datetime.date(2020, 3, 1), 20.74784769819613, 13),
#  ('eccbc8', datetime.date(2018, 1, 1), 20.71868584798014, 14),
#  ('eccbc8', datetime.date(2020, 7, 1), 19.41201700430472, 15),
#  ('eccbc8', datetime.date(2018, 9, 1), 19.205792937076858, 16),
#  ('eccbc8', datetime.date(2019, 12, 1), 18.989194840311292, 17),
#  ('eccbc8', datetime.date(2019, 8, 1), 18.851169747669623, 18),
#  ('eccbc8', datetime.date(2020, 1, 1), 18.53930667677136, 19),
#  ('eccbc8', datetime.date(2018, 3, 1), 18.42311827442451, 20),
#  ('eccbc8', datetime.date(2017, 9, 1), 17.467220421129106, 21),
#  ('eccbc8', datetime.date(2020, 4, 1), 17.41279026088193, 22),
#  ('eccbc8', datetime.date(2020, 8, 1), 17.24031818219035, 23),
#  ('eccbc8', datetime.date(2018, 11, 1), 16.850737144819764, 24),
#  ('eccbc8', datetime.date(2020, 12, 1), 15.180037736510243, 25),
#  ('eccbc8', datetime.date(2017, 5, 1), 13.91615505080341, 26),
#  ('eccbc8', datetime.date(2017, 4, 1), 13.70862084582193, 27),
#  ('eccbc8', datetime.date(2018, 2, 1), 13.065292165156428, 28),
#  ('eccbc8', datetime.date(2018, 4, 1), 12.986025858340229, 29),
#  ('eccbc8', datetime.date(2019, 2, 1), 12.8678028146274, 30),
#  ('eccbc8', datetime.date(2018, 8, 1), 12.66119181362977, 31),
#  ('eccbc8', datetime.date(2019, 3, 1), 11.619138037205198, 32),
#  ('eccbc8', datetime.date(2018, 5, 1), 11.1785340822297, 33),
#  ('eccbc8', datetime.date(2020, 2, 1), 11.051698009078239, 34),
#  ('eccbc8', datetime.date(2021, 2, 1), 10.8164882242454, 35),
#  ('eccbc8', datetime.date(2019, 10, 1), 10.73256396334302, 36),
#  ('eccbc8', datetime.date(2017, 8, 1), 10.30068397411383, 37),
#  ('eccbc8', datetime.date(2018, 12, 1), 9.92018533431406, 38),
#  ('eccbc8', datetime.date(2019, 5, 1), 9.49295173813791, 39),
#  ('eccbc8', datetime.date(2020, 10, 1), 9.43540135744862, 40),
#  ('eccbc8', datetime.date(2017, 7, 1), 8.919966538572515, 41),
#  ('eccbc8', datetime.date(2018, 6, 1), 8.56804312434114, 42),
#  ('eccbc8', datetime.date(2018, 7, 1), 8.53992998595533, 43),
#  ('eccbc8', datetime.date(2021, 7, 1), 8.47564682997529, 44),
#  ('eccbc8', datetime.date(2019, 9, 1), 8.219603590234174, 45),
#  ('eccbc8', datetime.date(2021, 4, 1), 7.95489198517501, 46),
#  ('eccbc8', datetime.date(2017, 6, 1), 7.47211911904888, 47),
#  ('eccbc8', datetime.date(2019, 4, 1), 6.98482767358943, 48),
#  ('eccbc8', datetime.date(2020, 11, 1), 4.52300102604365, 49),
#  ('eccbc8', datetime.date(2017, 11, 1), 4.28188605066094, 50),
#  ('eccbc8', datetime.date(2021, 6, 1), 2.164677426298807, 51),
#  ('eccbc8', datetime.date(2017, 3, 1), 1.60585448320578, 52),
#  ('eccbc8', datetime.date(2020, 6, 1), 0.1443428869052, 53)]
