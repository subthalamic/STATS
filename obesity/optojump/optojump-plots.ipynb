# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st
import statsmodels.formula.api as smf
from statsmodels.stats.anova import AnovaRM

# %%
o = pd.read_excel('OptoJumpSorted.xlsx', sheet_name='GeneralSbs')
ost = pd.read_excel('OptoJumpSorted.xlsx', sheet_name='GeneralSt')

# %%
ost.loc[:40, 'Test'] = 'final'
ost.loc[40:, 'Test'] = 'initial'

# %%
ost.columns
# Out:
# Index(['Index', 'Name', 'Test', 'Group', 'Sex', 'Weight', 'Height', 'WPX1J',
#        'StepWidth1J1', 'StepWidth1J2', 'TFlight1J', 'Elevation1J', 'NJumps',
#        'TFlight', 'TContact', 'Elevation', 'Power', 'Pace', 'RSI', 'WPX',
#        'WPY', 'StepWidth', 'Distance', 'TTotalSum', 'TTotalAvg', 'SlopeTF',
#        'SlopeTC', 'SlopeE', 'SlopePw', 'SlopePace', 'SlopeRSI',
#        'SlopeStepWidth', 'SlopeDistance', 'BoscoTFlight', 'BoscoTContact',
#        'BoscoElevation', 'BoscoPower', 'BoscoPace', 'BoscoRSI',
#        'BoscoStepWidth', 'BoscoDistance'],
#       dtype='object')

# %%
ost.columns = ['Index', 'name', 'test', 'grup', 'sex', 'greutate', 'height', 'WPX1J',
       'StepWidth1J1', 'StepWidth1J2', 'timp saritura unica', 'inaltime saritura unica', 'sarituri',
       'timp saritura', 'timp contact', 'inaltime', 'putere', 'viteza', 'IFR', 'distanta X',
       'distanta Y', 'distanta picioare', 'distanta', 'timp total', 'timp mediu', 'panta timp saritura',
       'panta timp contact', 'panta inaltime', 'panta putere', 'panta viteza', 'panta IFR',
       'panta distanta picioare', 'panta distanta', 'indice Bosco timp saritura', 'indice Bosco timp contact',
       'indice Bosco inaltime', 'indice Bosco putere', 'indice Bosco viteza', 'indice Bosco IFR',
       'indice Bosco distanta picioare', 'indice Bosco distanta']

# %%
for col in ost.columns[9:]:
    # sns.stripplot(ost, x='test', y=col)
    sns.violinplot(ost, hue='test', y=col, split=True)
    plt.show()
